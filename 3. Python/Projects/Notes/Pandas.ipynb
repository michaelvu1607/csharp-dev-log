# %%
import pandas as pd

# %% [markdown]
# SERIES | SERIES | SERIES | SERIES | SERIES | SERIES | SERIES | SERIES | SERIES | SERIES | SERIES

# %%
# 1. list
data = [100, 102, 104, 106, 108]
series = pd.Series(data, index=["a", "b", "c", "d", "e"])
print(series)
# Out:
# a    100
# b    102
# c    104
# d    106
# e    108
# dtype: int64

# %%
series.loc["a"] = 200
a = series.loc["a"]
print(series.loc["a"])
# Out:
# 200

# %%
print(series.iloc[0])
# Out:
# 200

# %%
print(series[series > 105])
# Out:
# a    200
# d    106
# e    108
# dtype: int64

# %%
# 2. dictionary
calories = {
    "Day 1": 1750,
    "Day 2": 2100,
    "Day 3": 1700
}
series = pd.Series(calories)
print(series)
# Out:
# Day 1    1750
# Day 2    2100
# Day 3    1700
# dtype: int64

# %%
series.loc["Day 3"] += 500
print(series.loc["Day 3"])
# Out:
# 2200

# %%
print(series[series < 2000])
# Out:
# Day 1    1750
# dtype: int64

# %% [markdown]
# DATAFRAMES | DATAFRAMES | DATAFRAMES | DATAFRAMES | DATAFRAMES | DATAFRAMES

# %%
data = {
    "Name": ["SpongeBob", "Patrick", "Squidward"],
    "Age": [30, 35, 50]
        }
df = pd.DataFrame(data, index=["Employee 1", "Employee 2", "Employee 3"])
print(df)
# Out:
#                  Name  Age
# Employee 1  SpongeBob   30
# Employee 2    Patrick   35
# Employee 3  Squidward   50

# %%
print(df.loc["Employee 2"])
print(df.iloc[2])
# Out:
# Name    Patrick
# Age          35
# Name: Employee 2, dtype: object
# Name    Squidward
# Age            50
# Name: Employee 3, dtype: object

# %%
# Add new column
df["Job"] = ["Cook", "N/A", "Cashier"]
print(df)
# Out:
#                  Name  Age      Job
# Employee 1  SpongeBob   30     Cook
# Employee 2    Patrick   35      N/A
# Employee 3  Squidward   50  Cashier

# %%
# Add new row -> add new row, then concatenate it
# each dictionary = one new row
new_rows = pd.DataFrame([
    {"Name": "Sandy", "Age": 28, "Job": "Engineer"},
    {"Name": "Krabs", "Age": 60, "Job": "Manager"}],
                       index=["Employee 4", "Employee 5"])
df = pd.concat([df, new_rows])
print(df)
# Out:
#                  Name  Age       Job
# Employee 1  SpongeBob   30      Cook
# Employee 2    Patrick   35       N/A
# Employee 3  Squidward   50   Cashier
# Employee 4      Sandy   28  Engineer
# Employee 5      Krabs   60   Manager

# %% [markdown]
# IMPORTING | IMPORTING | IMPORTING | IMPORTING | IMPORTING | IMPORTING

# %%
# can read .json as well; just change read_csv to read_json
df = pd.read_csv("pokemon.csv")
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire       NaN     0.6     8.5          0
# 4      5  Charmeleon      Fire       NaN     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water       NaN     0.5     9.0          0
# 7      8   Wartortle     Water       NaN     1.0    22.5          0
# 8      9   Blastoise     Water       NaN     1.6    85.5          0
# 9     10    Caterpie       Bug       NaN     0.3     2.9          0
# 10    11     Metapod       Bug       NaN     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %% [markdown]
# SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION | SELECTION

# %%
df = pd.read_csv("pokemon.csv")

# Selection by Column(s)
print(df[["Name", "Height", "Weight"]].to_string())
# Out:
#            Name  Height  Weight
# 0     Bulbasaur     0.7     6.9
# 1       Ivysaur     1.0    13.0
# 2      Venusaur     2.0   100.0
# 3    Charmander     0.6     8.5
# 4    Charmeleon     1.1    19.0
# 5     Charizard     1.7    90.5
# 6      Squirtle     0.5     9.0
# 7     Wartortle     1.0    22.5
# 8     Blastoise     1.6    85.5
# 9      Caterpie     0.3     2.9
# 10      Metapod     0.7     9.9
# 11   Butterfree     1.1    32.0
# 12       Weedle     0.3     3.2
# 13       Kakuna     0.6    10.0
# 14     Beedrill     1.0    29.5
# 15       Pidgey     0.3     1.8
# 16    Pidgeotto     1.1    30.0
# 17      Pidgeot     1.5    39.5
# 18      Rattata     0.3     3.5
# 19     Raticate     0.7    18.5
# 20      Spearow     0.3     2.0
# 21       Fearow     1.2    38.0
# 22        Ekans     2.0     6.9
# 23        Arbok     3.5    65.0
# 24      Pikachu     0.4     6.0
# 25       Raichu     0.8    30.0
# 26    Sandshrew     0.6    12.0
# 27    Sandslash     1.0    29.5
# ...

# %%
df = pd.read_csv("pokemon.csv", index_col="Name")

# Selection by Row(s)
print(df.loc["Pikachu"])
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object

# %%
# Select specific columns by using a list after row selection
print(df.loc["Charizard", ["Height", "Weight"]])
# Out:
# Height     1.7
# Weight    90.5
# Name: Charizard, dtype: float64

# %%
# Select a range of rows
print(df.loc["Charizard": "Pikachu"])
# Out:
#             No     Type1   Type2  Height  Weight  Legendary
# Name
# Charizard    6      Fire  Flying     1.7    90.5          0
# Squirtle     7     Water     NaN     0.5     9.0          0
# Wartortle    8     Water     NaN     1.0    22.5          0
# Blastoise    9     Water     NaN     1.6    85.5          0
# Caterpie    10       Bug     NaN     0.3     2.9          0
# Metapod     11       Bug     NaN     0.7     9.9          0
# Butterfree  12       Bug  Flying     1.1    32.0          0
# Weedle      13       Bug  Poison     0.3     3.2          0
# Kakuna      14       Bug  Poison     0.6    10.0          0
# Beedrill    15       Bug  Poison     1.0    29.5          0
# Pidgey      16    Normal  Flying     0.3     1.8          0
# Pidgeotto   17    Normal  Flying     1.1    30.0          0
# Pidgeot     18    Normal  Flying     1.5    39.5          0
# Rattata     19    Normal     NaN     0.3     3.5          0
# Raticate    20    Normal     NaN     0.7    18.5          0
# ...

# %%
# Section by row with indices
#  1: Row range; 2: Skip length; 3. Column range
print(df.iloc[0:11:2, 0:3])
# Out:
#             No  Type1   Type2
# Name
# Bulbasaur    1  Grass  Poison
# Venusaur     3  Grass  Poison
# Charmeleon   5   Fire     NaN
# Squirtle     7  Water     NaN
# Blastoise    9  Water     NaN
# Metapod     11    Bug     NaN

# %%
pokemon = input("Enter a Pokemon name: ").title().strip()
try:
    print(df.loc[pokemon])
except KeyError:
    print(f"{pokemon} Not Found")
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object

# %% [markdown]
# FILTERING | FILTERING | FILTERING | FILTERING | FILTERING | FILTERING

# %%
df = pd.read_csv("pokemon.csv")

# %%
tall_poke = df[df["Height"] >= 2]
print(tall_poke)
legendary = df[df["Legendary"] == True]
print(legendary)

# %%
# OR -> "|"
water_poke = df[(df["Type1"] == "Water") | (df["Type2"] == "Water")]
print(water_poke)

# %%
# AND -> "&"

# %%
ff_poke = df[(df["Type1"] == "Fire") & (df["Type2"] == "Flying")]
print(ff_poke)

# %% [markdown]
# AGGREGATION | AGGREGATION | AGGREGATION | AGGREGATION | AGGREGATION | AGGREGATION

# %%
df = pd.read_csv("pokemon.csv")

# %%
# functions applying to whole dataframe
print(df.mean(numeric_only=True))
print(df.sum(numeric_only=True))
print(df.min(numeric_only=True))
print(df.max(numeric_only=True))
print(df.count())

# %%
# Single Column
print(df["Height"].mean())
print(df["Height"].sum())
print(df["Height"].min())
print(df["Height"].max())
print(df["Type2"].count())

# %%
# groupby
group = df.groupby("Type1")
print(group["Height"].mean())
print(group["No"].count())

# %% [markdown]
# DATA CLEANING | DATA CLEANING | DATA CLEANING | DATA CLEANING | DATA CLEANING | DATA CLEANING

# %%
# Drop irrelevant columns
df = pd.read_csv("pokemon.csv")
df = df.drop(columns=["Legendary", "No"])
print(df)

# %%
# 1. Handle missing data ("dropna" = "drop not available or NaN")
# ex. within Type2, drop any rows missing a value
df = pd.read_csv("pokemon.csv")
df = df.dropna(subset=["Type2"])
print(df.to_string())

# %%
# 2. Handle missing data ("fillna")
# ex. replace any missing values with "None"
df = pd.read_csv("pokemon.csv")
df = df.fillna({"Type2": "None"})
print(df)

# %%
# Fix inconsistent values
# ex. in column "Type1", change all instances of "grass" to "GRASS
df = pd.read_csv("pokemon.csv")
df["Type1"] = df["Type1"].replace({"Grass":"GRASS",
                                  "Fire":"FIRE",
                                  "Water":"WATER"})
print(df.to_string())

# %%
# Standardize text
df = pd.read_csv("pokemon.csv")
df["Name"] = df["Name"].str.upper()
print(df.to_string())

# %%
# Fix data types
df = pd.read_csv("pokemon.csv")
df["Legendary"] = df["Legendary"].astype(bool)
print(df.to_string())

# %% [markdown]
# OTHER | OTHER | OTHER | OTHER | OTHER | OTHER | OTHER

# %%
# df.describe()
df = pd.read_csv("pokemon.csv")
description = df.describe()
print(description)
