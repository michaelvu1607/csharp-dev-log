# %%
import numpy as np
import pandas as pd

# Set seed for reproducibility
np.random.seed(42)
num_sessions = 120

# 1. Generate Session Logs
player_ids = np.random.choice([f"P_{i:03d}" for i in range(1, 21)], size=num_sessions)
timestamps = pd.date_range(start="2026-08-01", periods=num_sessions, freq="2h")
duration_mins = np.random.uniform(10, 180, num_sessions)
damage_dealt = np.random.normal(5000, 1500, num_sessions).clip(500, 10000)
xp_gained = damage_dealt * np.random.uniform(0.1, 0.25, num_sessions)

# Introduce missing/corrupted values (dropped telemetry)
damage_dealt[::12] = np.nan

sessions_df = pd.DataFrame({
    'session_id': [f"S_{i:04d}" for i in range(1, num_sessions + 1)],
    'player_id': player_ids,
    'timestamp': timestamps,
    'duration_mins': np.round(duration_mins, 1),
    'damage_dealt': damage_dealt,
    'xp_gained': np.round(xp_gained, 0)
})
sessions_df.to_csv("player_sessions.csv", index=False)

# 2. Generate Store Purchases Log
num_purchases = 40
buyer_ids = np.random.choice(np.unique(player_ids), size=num_purchases)
item_types = np.random.choice(['Cosmetic', 'XP Boost', 'Battle Pass', 'Starter Pack'], size=num_purchases)
price_usd = np.random.choice([0.99, 4.99, 9.99, 19.99], size=num_purchases, p=[0.4, 0.3, 0.2, 0.1])

purchases_df = pd.DataFrame({
    'purchase_id': [f"TX_{i:04d}" for i in range(1, num_purchases + 1)],
    'player_id': buyer_ids,
    'item_type': item_types,
    'amount_usd': price_usd
})
purchases_df.to_csv("store_purchases.csv", index=False)

print("Setup Complete! 'player_sessions.csv' and 'store_purchases.csv' created.")
# Out:
# Setup Complete! 'player_sessions.csv' and 'store_purchases.csv' created.

# %%
ps = pd.read_csv("player_sessions.csv")
sp = pd.read_csv("store_purchases.csv")

ps = ps.fillna({"damage_dealt": 0})
print(ps)
# Out:
#     session_id player_id            timestamp  duration_mins  damage_dealt  \
# 0       S_0001     P_007  2026-08-01 00:00:00           15.3      0.000000
# 1       S_0002     P_020  2026-08-01 02:00:00          118.2   7845.189474
# 2       S_0003     P_015  2026-08-01 04:00:00           63.4   4631.917826
# 3       S_0004     P_011  2026-08-01 06:00:00           96.5   3869.395753
# 4       S_0005     P_008  2026-08-01 08:00:00          164.3   3665.728356
# ..         ...       ...                  ...            ...           ...
# 115     S_0116     P_015  2026-08-10 14:00:00           50.3   5993.196012
# 116     S_0117     P_015  2026-08-10 16:00:00           65.3   7379.025224
# 117     S_0118     P_010  2026-08-10 18:00:00          136.9   3143.276752
# 118     S_0119     P_013  2026-08-10 20:00:00          120.4   8199.550062
# 119     S_0120     P_019  2026-08-10 22:00:00          154.4   2071.868301
#
#      xp_gained
# 0       1504.0
# 1       1239.0
# 2       1131.0
# 3        912.0
# 4        474.0
# ..         ...
# 115     1070.0
# 116     1435.0
# 117      642.0
# 118     1379.0
# 119      402.0
#
# [120 rows x 6 columns]

# %%
ps_dd_np = ps["damage_dealt"].to_numpy()
print(ps_dd_np)
ps_dm_np = ps["duration_mins"].to_numpy()
print(ps_dm_np)

dpm = ps_dd_np / ps_dm_np
print(dpm)
# Out:
# [    0.          7845.18947398  4631.917826    3869.39575346
#   3665.72835556  3776.28457255  4884.34743588  5511.72796222
#   5415.036199    6240.77487355  5019.50283782  7180.30111574
#      0.          9080.25374988  5938.50102165  3714.26366538
#   3393.66125291  5723.70862286  4664.80582201  6071.00074114
#  121.91654893  45.15671309  83.20518879  18.90990183 134.67808821
#   63.05267696 137.20157512  45.74271149  35.24495642   0.
#   52.18324812  54.95792005  62.72699129  27.20945051  83.6330507
#  267.45607457  24.23689724  34.73776298  52.3975432   53.3965132
#   70.75953841   0.          21.31334485  28.73848117  21.93776457
#   62.54086445 117.4809849  115.73155387  31.91714291  63.32369526
#  245.36265286 247.06027942  40.84160905   0.         152.63150701
#   51.2932192   32.12911195  42.25747622  91.93408742  39.43765078
#  119.14902608 113.00191768  22.96038533  68.10257527  13.41883614]

# %%
ps["dpm"] = dpm
print(ps)
# Out:
#     session_id player_id            timestamp  duration_mins  damage_dealt  \
# 0       S_0001     P_007  2026-08-01 00:00:00           15.3      0.000000
# 1       S_0002     P_020  2026-08-01 02:00:00          118.2   7845.189474
# 2       S_0003     P_015  2026-08-01 04:00:00           63.4   4631.917826
# 3       S_0004     P_011  2026-08-01 06:00:00           96.5   3869.395753
# 4       S_0005     P_008  2026-08-01 08:00:00          164.3   3665.728356
# ..         ...       ...                  ...            ...           ...
# 115     S_0116     P_015  2026-08-10 14:00:00           50.3   5993.196012
# 116     S_0117     P_015  2026-08-10 16:00:00           65.3   7379.025224
# 117     S_0118     P_010  2026-08-10 18:00:00          136.9   3143.276752
# 118     S_0119     P_013  2026-08-10 20:00:00          120.4   8199.550062
# 119     S_0120     P_019  2026-08-10 22:00:00          154.4   2071.868301
#
#      xp_gained         dpm
# 0       1504.0    0.000000
# 1       1239.0   66.372161
# 2       1131.0   73.058641
# 3        912.0   40.097365
# 4        474.0   22.311189
# ..         ...         ...
# 115     1070.0  119.149026
# 116     1435.0  113.001918
# 117      642.0   22.960385
# 118     1379.0   68.102575
# 119      402.0   13.418836
#
# [120 rows x 7 columns]

# %%
sp_sum = sp["amount_usd"].sum()
print(sp_sum)
# Out:
# 274.6

# %%
# Create a clean, flat summary table
sp_aggregated = sp.groupby("player_id", as_index=False).agg(
    amount_usd=("amount_usd", "sum"),
)

merged = pd.merge(ps, sp_aggregated, on="player_id", how="left")
merged = merged.fillna({"amount_usd": 0})
print(merged)
# Out:
#     session_id player_id            timestamp  duration_mins  damage_dealt  \
# 0       S_0001     P_007  2026-08-01 00:00:00           15.3      0.000000
# 1       S_0002     P_020  2026-08-01 02:00:00          118.2   7845.189474
# 2       S_0003     P_015  2026-08-01 04:00:00           63.4   4631.917826
# 3       S_0004     P_011  2026-08-01 06:00:00           96.5   3869.395753
# 4       S_0005     P_008  2026-08-01 08:00:00          164.3   3665.728356
# ..         ...       ...                  ...            ...           ...
# 115     S_0116     P_015  2026-08-10 14:00:00           50.3   5993.196012
# 116     S_0117     P_015  2026-08-10 16:00:00           65.3   7379.025224
# 117     S_0118     P_010  2026-08-10 18:00:00          136.9   3143.276752
# 118     S_0119     P_013  2026-08-10 20:00:00          120.4   8199.550062
# 119     S_0120     P_019  2026-08-10 22:00:00          154.4   2071.868301
#
#      xp_gained         dpm  amount_usd
# 0       1504.0    0.000000        0.00
# 1       1239.0   66.372161        9.99
# 2       1131.0   73.058641       19.98
# 3        912.0   40.097365        0.99
# 4        474.0   22.311189        6.97
# ..         ...         ...         ...
# 115     1070.0  119.149026       19.98
# 116     1435.0  113.001918       19.98
# 117      642.0   22.960385       14.98
# 118     1379.0   68.102575       25.97
# 119      402.0   13.418836        4.99
#
# [120 rows x 8 columns]

# %%
merged["Engagement Level"] = np.where(merged["duration_mins"] >= 60, "High Engagement", "Low Engagement")
print(merged)
# Out:
#     session_id player_id            timestamp  duration_mins  damage_dealt  \
# 0       S_0001     P_007  2026-08-01 00:00:00           15.3      0.000000
# 1       S_0002     P_020  2026-08-01 02:00:00          118.2   7845.189474
# 2       S_0003     P_015  2026-08-01 04:00:00           63.4   4631.917826
# 3       S_0004     P_011  2026-08-01 06:00:00           96.5   3869.395753
# 4       S_0005     P_008  2026-08-01 08:00:00          164.3   3665.728356
# ..         ...       ...                  ...            ...           ...
# 115     S_0116     P_015  2026-08-10 14:00:00           50.3   5993.196012
# 116     S_0117     P_015  2026-08-10 16:00:00           65.3   7379.025224
# 117     S_0118     P_010  2026-08-10 18:00:00          136.9   3143.276752
# 118     S_0119     P_013  2026-08-10 20:00:00          120.4   8199.550062
# 119     S_0120     P_019  2026-08-10 22:00:00          154.4   2071.868301
#
#      xp_gained         dpm  amount_usd Engagement Level
# 0       1504.0    0.000000        0.00   Low Engagement
# 1       1239.0   66.372161        9.99  High Engagement
# 2       1131.0   73.058641       19.98  High Engagement
# 3        912.0   40.097365        0.99  High Engagement
# 4        474.0   22.311189        6.97  High Engagement
# ..         ...         ...         ...              ...
# 115     1070.0  119.149026       19.98   Low Engagement
# 116     1435.0  113.001918       19.98  High Engagement
# 117      642.0   22.960385       14.98  High Engagement
# 118     1379.0   68.102575       25.97  High Engagement
# 119      402.0   13.418836        4.99  High Engagement
#
# [120 rows x 9 columns]

# %%
merged["is_whale"] = merged["amount_usd"] >= 10
print(merged)
# Out:
#     session_id player_id            timestamp  duration_mins  damage_dealt  \
# 0       S_0001     P_007  2026-08-01 00:00:00           15.3      0.000000
# 1       S_0002     P_020  2026-08-01 02:00:00          118.2   7845.189474
# 2       S_0003     P_015  2026-08-01 04:00:00           63.4   4631.917826
# 3       S_0004     P_011  2026-08-01 06:00:00           96.5   3869.395753
# 4       S_0005     P_008  2026-08-01 08:00:00          164.3   3665.728356
# ..         ...       ...                  ...            ...           ...
# 115     S_0116     P_015  2026-08-10 14:00:00           50.3   5993.196012
# 116     S_0117     P_015  2026-08-10 16:00:00           65.3   7379.025224
# 117     S_0118     P_010  2026-08-10 18:00:00          136.9   3143.276752
# 118     S_0119     P_013  2026-08-10 20:00:00          120.4   8199.550062
# 119     S_0120     P_019  2026-08-10 22:00:00          154.4   2071.868301
#
#      xp_gained         dpm  amount_usd Engagement Level  is_whale
# 0       1504.0    0.000000        0.00   Low Engagement     False
# 1       1239.0   66.372161        9.99  High Engagement     False
# 2       1131.0   73.058641       19.98  High Engagement      True
# 3        912.0   40.097365        0.99  High Engagement     False
# 4        474.0   22.311189        6.97  High Engagement     False
# ..         ...         ...         ...              ...       ...
# 115     1070.0  119.149026       19.98   Low Engagement      True
# 116     1435.0  113.001918       19.98  High Engagement      True
# 117      642.0   22.960385       14.98  High Engagement      True
# 118     1379.0   68.102575       25.97  High Engagement      True
# 119      402.0   13.418836        4.99  High Engagement     False
#
# [120 rows x 10 columns]

# %%
# find all paying players -> find avg dpm
paying_players = merged[merged["amount_usd"] > 0]
nonpaying_players = merged[merged["amount_usd"] == 0]
print(paying_players["dpm"].mean())
print(nonpaying_players["dpm"].mean())
# Out:
# 77.37073836302442
# 92.59453207707577
